# %% [markdown]
# # Execute final model and generate visualization

# %% [markdown]
# # Setup

# %%
import pandas as pd
import psycopg2 as pg
import os
import sys
import pandas.io.sql as pd_sql
import numpy as np
import sqlalchemy
project_dir = str(os.path.dirname(os.path.abspath('')))
print(project_dir)
sys.path.append(project_dir)
import matplotlib.pyplot as plt
from src.pickle.pickle_util import save_pickle, load_pickle

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

my_random_state = 72
# Out:
# /Users/erik/metis/data_hailing

# %% [markdown]
# ## Load processed data as it was in 03_feat_eng_and_model notebook

# %%
file_path = project_dir + '/data/processed/' + 'df_merge_trip_income_from_03_feat_notebook'
df_merge_trip_income = pd.read_csv(file_path)

# %%
df_merge_trip_income
# Out:
#         community_area_number trip_start_timestamp  trip_seconds  trip_miles  \
# 0                           8  2019-07-17 11:30:00         857.0         4.5
# 1                           8  2019-07-17 23:45:00         779.0         5.4
# 2                           8  2019-07-17 22:30:00         671.0         4.2
# 3                           8  2019-07-17 16:45:00         460.0         1.0
# 4                           8  2019-07-17 09:30:00         744.0         2.0
# ...                       ...                  ...           ...         ...
# 185174                     54  2019-07-17 14:30:00         864.0         3.9
# 185175                     55  2019-07-17 17:45:00         387.0         1.8
# 185176                     55  2019-07-17 18:00:00        1112.0         8.7
# 185177                     74  2019-07-17 08:30:00        2265.0        13.4
# 185178                     74  2019-07-17 08:30:00        2894.0        18.8
#
#         fare  pickup_centroid_latitude  pickup_centroid_longitude  \
# 0       10.0                 41.907520                 -87.626659
# 1       10.0                 41.900221                 -87.629105
# 2        7.5                 41.892042                 -87.631864
# 3       10.0                 41.891972                 -87.612945
# 4        7.5                 41.905858                 -87.630865
# ...      ...                       ...                        ...
# 185174   7.5                 41.650222                 -87.599463
# 185175   5.0                 41.651922                 -87.564929
# 185176  12.5                 41.651922                 -87.564929
# 185177  22.5                 41.687239                 -87.719313
# 185178  30.0                 41.687239                 -87.719313
#
#         per_capita_income_  part_of_day  surge_estimate
# 0                    88669            2        1.057538
# 1                    88669            5        0.995199
# 2                    88669            5        0.879183
# 3                    88669            4        2.106109
# 4                    88669            2        1.122956
# ...                    ...          ...             ...
# 185174                8201            3        0.842076
# 185175               22677            4        0.950209
# 185176               22677            4        0.871371
# 185177               34381            2        0.987042
# 185178               34381            2        0.996165
#
# [185179 rows x 10 columns]

# %% [markdown]
# ## Load pickle of random forest model

# %%
file_path = project_dir + '/models/' + 'random_forest_from_02_feat_eng_and_model_notebook.pickle'  ### eka should be _03_feat_
rf_model = load_pickle(file_path)

# %% [markdown]
# ## Get X and y for modeling

# %%
def get_X(df_merge_trip_income, dummies_on_part_of_day=True):
    X = df_merge_trip_income[['pickup_centroid_latitude', 'pickup_centroid_longitude', 'per_capita_income_', 'part_of_day']]
    if dummies_on_part_of_day:
        X = pd.get_dummies(X, columns=['part_of_day'])
    else:
        X = X.drop['part_of_day']
    return X


def get_y(df_merge_trip_income, surge_cutoff=1.1):
    y = df_merge_trip_income.loc[:, 'surge_estimate'] > surge_cutoff
    return y

# %%
X = get_X(df_merge_trip_income)
y = get_y(df_merge_trip_income)

# %% [markdown]
# # Use model to generate predictions for visualizing

# %%
predict_proba_threshold = .45
df_merge_trip_income['true_y'] = y
df_merge_trip_income['predict_y_hat'] = y_pred = (rf_model.predict_proba(X))[:,1] > predict_proba_threshold
df_merge_trip_income['predict_proba_y_hat'] = rf_model.predict_proba(X)[:,1]

# %%
df_merge_trip_income[df_merge_trip_income['predict_y_hat']==True]
# Out:
#         community_area_number trip_start_timestamp  trip_seconds  trip_miles  \
# 259                         8  2019-07-17 01:30:00         269.0         0.9
# 440                         8  2019-07-17 16:30:00         907.0         2.5
# 532                         8  2019-07-17 18:15:00        1227.0         2.0
# 706                         8  2019-07-17 19:00:00         746.0         5.2
# 785                         8  2019-07-17 18:45:00         537.0         1.4
# ...                       ...                  ...           ...         ...
# 185073                     48  2019-07-17 18:15:00         730.0         3.9
# 185077                     48  2019-07-17 19:15:00         599.0         3.0
# 185091                     48  2019-07-17 18:15:00        2547.0        17.8
# 185138                     18  2019-07-17 14:15:00         345.0         1.5
# 185144                     18  2019-07-17 15:45:00        2520.0         9.7
#
#         fare  pickup_centroid_latitude  pickup_centroid_longitude  \
# 259      5.0                 41.891972                 -87.612945
# 440      7.5                 41.907413                 -87.640902
# 532      7.5                 41.907413                 -87.640902
# 706     10.0                 41.907413                 -87.640902
# 785      5.0                 41.907413                 -87.640902
# ...      ...                       ...                        ...
# 185073  10.0                 41.728456                 -87.575637
# 185077   7.5                 41.735249                 -87.575637
# 185091  22.5                 41.728456                 -87.575637
# 185138   7.5                 41.934487                 -87.798636
# 185144  22.5                 41.934487                 -87.798636
#
#         per_capita_income_  part_of_day  surge_estimate  true_y  \
# 259                  88669            0        1.251008    True
# 440                  88669            4        0.971974   False
# 532                  88669            4        0.899598   False
# 706                  88669            4        1.026293   False
# 785                  88669            4        0.926832   False
# ...                    ...          ...             ...     ...
# 185073               28887            4        1.183921    True
# 185077               28887            4        1.050913   False
# 185091               28887            4        0.804477   False
# 185138               22014            3        1.552440    True
# 185144               22014            3        1.117464    True
#
#         predict_y_hat  predict_proba_y_hat
# 259              True             0.511066
# 440              True             0.455459
# 532              True             0.455459
# 706              True             0.455459
# 785              True             0.455459
# ...               ...                  ...
# 185073           True             0.484464
# 185077           True             0.510417
# 185091           True             0.484464
# 185138           True             0.824693
# 185144           True             0.824693
#
# [1802 rows x 13 columns]

# %% [markdown]
# # Evaluate final model performance

# %%
confusion_matrix(df_merge_trip_income.loc[:, 'true_y'], df_merge_trip_income.loc[:, 'predict_y_hat'])
# Out:
# array([[136520,    936],
#        [ 46857,    866]])

# %%
accuracy_score(df_merge_trip_income.loc[:, 'true_y'], df_merge_trip_income.loc[:, 'predict_y_hat'])
# Out:
# 0.7419091797666042

# %%
precision_score(df_merge_trip_income.loc[:, 'true_y'], df_merge_trip_income.loc[:, 'predict_y_hat'])
# Out:
# 0.48057713651498335

# %%
recall_score(df_merge_trip_income.loc[:, 'true_y'], df_merge_trip_income.loc[:, 'predict_y_hat'])
# Out:
# 0.018146386438404962

# %%
rf_model.feature_importances_
# Out:
# array([0.29218812, 0.31202335, 0.14484304, 0.01142502, 0.01571451,
#        0.02483924, 0.0262007 , 0.1447239 , 0.02804212])

# %%
X.columns
# Out:
# Index(['pickup_centroid_latitude', 'pickup_centroid_longitude',
#        'per_capita_income_', 'part_of_day_0', 'part_of_day_1', 'part_of_day_2',
#        'part_of_day_3', 'part_of_day_4', 'part_of_day_5'],
#       dtype='object')

# %% [markdown]
# # Save to csv for work in Tableau

# %%
file_path = project_dir + '/data/processed/' + 'df_merge_trip_income_with_y_pred_from_scratch_08_viz.csv'
# assert not os.path.exists(file_path)
# df_merge_trip_income.to_csv(file_path)

# %%
df_merge_trip_income
# Out:
#         community_area_number trip_start_timestamp  trip_seconds  trip_miles  \
# 0                           8  2019-07-17 11:30:00         857.0         4.5
# 1                           8  2019-07-17 23:45:00         779.0         5.4
# 2                           8  2019-07-17 22:30:00         671.0         4.2
# 3                           8  2019-07-17 16:45:00         460.0         1.0
# 4                           8  2019-07-17 09:30:00         744.0         2.0
# ...                       ...                  ...           ...         ...
# 185174                     54  2019-07-17 14:30:00         864.0         3.9
# 185175                     55  2019-07-17 17:45:00         387.0         1.8
# 185176                     55  2019-07-17 18:00:00        1112.0         8.7
# 185177                     74  2019-07-17 08:30:00        2265.0        13.4
# 185178                     74  2019-07-17 08:30:00        2894.0        18.8
#
#         fare  pickup_centroid_latitude  pickup_centroid_longitude  \
# 0       10.0                 41.907520                 -87.626659
# 1       10.0                 41.900221                 -87.629105
# 2        7.5                 41.892042                 -87.631864
# 3       10.0                 41.891972                 -87.612945
# 4        7.5                 41.905858                 -87.630865
# ...      ...                       ...                        ...
# 185174   7.5                 41.650222                 -87.599463
# 185175   5.0                 41.651922                 -87.564929
# 185176  12.5                 41.651922                 -87.564929
# 185177  22.5                 41.687239                 -87.719313
# 185178  30.0                 41.687239                 -87.719313
#
#         per_capita_income_  part_of_day  surge_estimate  true_y  \
# 0                    88669            2        1.057538   False
# 1                    88669            5        0.995199   False
# 2                    88669            5        0.879183   False
# 3                    88669            4        2.106109    True
# 4                    88669            2        1.122956    True
# ...                    ...          ...             ...     ...
# 185174                8201            3        0.842076   False
# 185175               22677            4        0.950209   False
# 185176               22677            4        0.871371   False
# 185177               34381            2        0.987042   False
# 185178               34381            2        0.996165   False
#
#         predict_y_hat  predict_proba_y_hat
# 0               False             0.336938
# 1               False             0.263608
# 2               False             0.262218
# 3               False             0.406936
# 4               False             0.294096
# ...               ...                  ...
# 185174          False             0.000000
# 185175          False             0.047727
# 185176          False             0.047727
# 185177          False             0.043755
# 185178          False             0.043755
#
# [185179 rows x 13 columns]

# %% [markdown]
# Actually, I think I need to group stuff by community area, and possibly also by time of day

# %%
group_by_com_part = df_merge_trip_income.groupby(['community_area_number', 'part_of_day']).mean().reset_index()

# %%
group_by_com_part.dtypes
# Out:
# community_area_number          int64
# part_of_day                    int64
# trip_seconds                 float64
# trip_miles                   float64
# fare                         float64
# pickup_centroid_latitude     float64
# pickup_centroid_longitude    float64
# per_capita_income_             int64
# surge_estimate               float64
# true_y                       float64
# predict_y_hat                float64
# predict_proba_y_hat          float64
# dtype: object

# %%
group_by_com_part
# Out:
#      community_area_number  part_of_day  trip_seconds  trip_miles       fare  \
# 0                        1            0    727.666667    4.416667  10.416667
# 1                        1            1   1759.525862   11.432759  17.758621
# 2                        1            2   1519.996721    7.866557  14.032787
# 3                        1            3   1424.195122    6.619919  12.063008
# 4                        1            4   1308.970588    4.972876  10.882353
# ..                     ...          ...           ...         ...        ...
# 418                     77            1   1508.385870    9.540217  15.611413
# 419                     77            2   1391.269231    7.247059  13.540724
# 420                     77            3   1213.179558    5.846133  11.180939
# 421                     77            4   1112.619469    4.310619  10.039823
# 422                     77            5    759.213270    4.057109   8.246445
#
#      pickup_centroid_latitude  pickup_centroid_longitude  per_capita_income_  \
# 0                   42.006743                 -87.666754               23939
# 1                   42.007966                 -87.667126               23939
# 2                   42.009273                 -87.668791               23939
# 3                   42.008554                 -87.668277               23939
# 4                   42.007989                 -87.669120               23939
# ..                        ...                        ...                 ...
# 418                 41.987117                 -87.662642               33385
# 419                 41.985874                 -87.662695               33385
# 420                 41.986197                 -87.662646               33385
# 421                 41.986124                 -87.662472               33385
# 422                 41.984322                 -87.664814               33385
#
#      surge_estimate    true_y  predict_y_hat  predict_proba_y_hat
# 0          1.144967  0.250000       0.250000             0.193445
# 1          0.932143  0.051724       0.000000             0.034690
# 2          0.952416  0.131148       0.000000             0.121355
# 3          0.918597  0.154472       0.000000             0.159436
# 4          0.972037  0.267974       0.000000             0.265361
# ..              ...       ...            ...                  ...
# 418        0.947962  0.076087       0.000000             0.072673
# 419        0.978527  0.140271       0.000000             0.141689
# 420        0.932613  0.154696       0.000000             0.145953
# 421        1.005718  0.269027       0.056637             0.267360
# 422        0.964561  0.199052       0.037915             0.177557
#
# [423 rows x 12 columns]

# %%
file_path = project_dir + '/data/processed/' + 'group_by_com_part_from_scratch_08_viz.csv'
# assert not os.path.exists(file_path)
# group_by_com_part.to_csv(file_path)
